# %%
# Cell 1: Imports
import os
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, random_split

from gan_utils.io import H5ImageDataset
from gan.model import Generator, Discriminator, Encoder, DiscriminatorFeatures
from gan.trainer import Trainer

import matplotlib.pyplot as plt
import glob

# %%
# ==== Global config (single source of truth) ====
CONFIG = {
    "h5_path": "spirals_only.h5",
    "parquet_path": "/projects/standard/fortson/shared/raj00075/mask_labels_anomaly_spirals_h5.gzip",
    "outdir": "/projects/standard/fortson/shared/raj00075/outputs_spirals",
    "gan_ckpt_dir": "/projects/standard/fortson/shared/raj00075/outputs_spirals/gan_checkpoints",

    "batch_size": 64,
    "workers": 8,
    "val_split": 0.1,

    "image_size": 256,
    "n_z": 256,

    "run_epochs": 100,      # how many epochs per run (per resume)
    "g_lr": 1e-5,
    "d_lr": 1e-5,
    "lr_decay": 0.99,
    "decay_freq": 10,
    "save_freq": 10,

    "seed": 42,
    "device": "cuda" if torch.cuda.is_available() else "cpu",
}

# %%
# ==== Cell 2: Utilities ====
def set_seed(seed: int = 42):
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def ensure_dir(path: str):
    if path and not os.path.exists(path):
        os.makedirs(path, exist_ok=True)

# %%
def make_dataloaders(config):
    df = pd.read_parquet(config["parquet_path"])
    dataset = H5ImageDataset(df, config["h5_path"], transforms=None)

    n_total = len(dataset)
    n_val = int(config["val_split"] * n_total)
    n_train = n_total - n_val

    g = torch.Generator().manual_seed(config["seed"])
    train_ds, val_ds = random_split(dataset, [n_train, n_val], generator=g)

    train_loader = DataLoader(
        train_ds,
        batch_size=config["batch_size"],
        shuffle=True,
        num_workers=config["workers"],
        pin_memory=True,
        persistent_workers=True,
    )
    val_loader = DataLoader(
        val_ds,
        batch_size=config["batch_size"],
        shuffle=False,
        num_workers=config["workers"],
        pin_memory=True,
        persistent_workers=True,
    )
    return train_loader, val_loader


def build_models(config):
    gen = Generator(
        n_z=config["n_z"],
        input_filt=config["image_size"],
        final_size=config["image_size"],
        n_layers=6,
        out_channels=3,
        norm=False,
        pool=False,
    )
    disc = Discriminator(
        in_channels=3,
        n_layers=6,
        input_size=config["image_size"],
        norm=False,
        pool=False,
    )
    return gen, disc

# %%
def find_last_epoch_and_load(config, gen, disc):
    ckpt_dir = config["gan_ckpt_dir"]
    ckpts_g = sorted(glob.glob(os.path.join(ckpt_dir, "generator_ep_*.pth")))
    ckpts_d = sorted(glob.glob(os.path.join(ckpt_dir, "discriminator_ep_*.pth")))

    if not ckpts_g or not ckpts_d:
        print("No previous checkpoints found. Starting from scratch.")
        return gen, disc, 0

    latest_g = ckpts_g[-1]
    latest_d = ckpts_d[-1]
    last_epoch = int(latest_g.split("_ep_")[1].split(".")[0])
    print("Last completed epoch:", last_epoch)

    gen.load_state_dict(torch.load(latest_g, map_location=config["device"]))
    disc.load_state_dict(torch.load(latest_d, map_location=config["device"]))
    print("Loaded generator + discriminator.")

    return gen, disc, last_epoch


def merge_and_save_losses(ckpt_dir, G_loss_ep, D_loss_ep):
    loss_file = os.path.join(ckpt_dir, "loss_values.npy")

    if os.path.exists(loss_file):
        old_G, old_D = np.load(loss_file, allow_pickle=True)
        full_G = list(old_G) + list(G_loss_ep)
        full_D = list(old_D) + list(D_loss_ep)
        print(f"Merged with previous history: now {len(full_G)} epochs total.")
    else:
        full_G = list(G_loss_ep)
        full_D = list(D_loss_ep)
        print(f"Saved first loss history with {len(full_G)} epochs.")

    np.save(loss_file, np.array([full_G, full_D], dtype=object))
    return full_G, full_D


def save_loss_chunk(config, G_loss_ep, D_loss_ep):
    ckpt_dir = config["gan_ckpt_dir"]

    # Create directory if missing
    os.makedirs(ckpt_dir, exist_ok=True)

    # Find all existing chunk files
    existing = [
        f for f in os.listdir(ckpt_dir)
        if f.startswith("losses_run_") and f.endswith(".npy")
    ]

    # Extract run numbers safely
    run_ids = []
    for f in existing:
        try:
            num = int(f.split("_")[2].split(".")[0])
            run_ids.append(num)
        except:
            pass

    # Determine next run ID
    next_id = max(run_ids) + 1 if run_ids else 1

    # Build filename
    filename = os.path.join(ckpt_dir, f"losses_run_{next_id:04d}.npy")

    # Save chunk
    np.save(filename, np.array([G_loss_ep, D_loss_ep], dtype=object))

    print(f"Saved loss chunk to {filename}")

# %%
# ==== Main training / resume pipeline ====
set_seed(CONFIG["seed"])
ensure_dir(CONFIG["outdir"])
ensure_dir(CONFIG["gan_ckpt_dir"])

# SECTION 4 — Load metadata + dataloaders
train_loader, val_loader = make_dataloaders(CONFIG)

# SECTION 5 — Build models
gen, disc = build_models(CONFIG)
gen = gen.to(CONFIG["device"])
disc = disc.to(CONFIG["device"])

# Quick sanity check
imgs = next(iter(train_loader))          # dataset returns just img
print("Real batch shape:", imgs.shape)

z = torch.randn(4, gen.n_z).to(CONFIG["device"])
fake = gen(z)
print("Fake batch shape:", fake.shape)

# Resume from latest checkpoints if they exist
gen, disc, last_epoch = find_last_epoch_and_load(CONFIG, gen, disc)

# Create Trainer
trainer = Trainer(
    generator=gen,
    discriminator=disc,
    savefolder=CONFIG["gan_ckpt_dir"],
    device=CONFIG["device"],
)

# If Trainer supports 'start', set it
if hasattr(trainer, "start"):
    trainer.start = last_epoch + 1
    print(f"Resuming from epoch {trainer.start}")
else:
    print(f"Trainer has no 'start' attribute; training API will handle epochs internally.")
# Out:
# Real batch shape: torch.Size([64, 3, 256, 256])
# Fake batch shape: torch.Size([4, 3, 256, 256])
# Last completed epoch: 350
# ...

# %%
# Target total epochs for this run
target_epochs = last_epoch + CONFIG["run_epochs"]

# # === Train (or resume) ===
# G_loss_ep, D_loss_ep = trainer.train(
#     train_data=train_loader,
#     val_data=val_loader,
#     epochs=target_epochs,
#     dsc_learning_rate=CONFIG["d_lr"],
#     gen_learning_rate=CONFIG["g_lr"],
#     save_freq=CONFIG["save_freq"],
#     lr_decay=CONFIG["lr_decay"],
#     decay_freq=CONFIG["decay_freq"],
# )

# === Train (or resume) ===
G_loss_ep, D_loss_ep = trainer.train(
    train_data=train_loader,
    val_data=val_loader,
    epochs=target_epochs,
    dsc_learning_rate=CONFIG["d_lr"],
    gen_learning_rate=CONFIG["g_lr"],
    save_freq=CONFIG["save_freq"],
    lr_decay=CONFIG["lr_decay"],
    decay_freq=CONFIG["decay_freq"],
)

print("Finished training run.")

# === Save this chunk separately ===
# save_loss_chunk(CONFIG, G_loss_ep, D_loss_ep)


print("Finished training run.")
# Out:
# Epoch 351 -- lr: 7.034e-06, 7.034e-06
# -------------------------------------------------------
# Training:   0%|          | 0/405 [00:00<?, ?it/s]/users/5/raj00075/Desktop/Anomaly_detection/KM_VERITAS_GAN/gan/trainer.py:71: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /users/5/raj00075/Desktop/Anomaly_detection/KM_VERITAS_GAN/gan/trainer.py:85: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Training: 100%|██████████| 405/405 [02:12<00:00,  3.06it/s, gen: 1.83e+00 disc: -5.58e+00 w_dist: -6.30e+00 grad_penalty: 7.16e-01]
# [Saved epoch loss] /projects/standard/fortson/shared/raj00075/outputs_spirals/gan_checkpoints/losses_epoch_0351.npy
# Validation: 100%|██████████| 45/45 [00:10<00:00,  4.37it/s, gen: -4.27e+00 disc: -4.59e+00 w_dist: -5.44e+00 grad_penalty: 8.47e-01]
# ...

# %%
# === Merge loss history across runs ===
full_G, full_D = merge_and_save_losses(CONFIG["gan_ckpt_dir"], G_loss_ep, D_loss_ep)

# === Plot full loss history ===
plt.figure(figsize=(10, 5))
plt.plot(full_G, label="Gen loss", color="red")
plt.plot(full_D, label="Disc loss", color="blue")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("GAN Losses (Full Training History)")
plt.legend()
plt.tight_layout()

loss_plot_path = os.path.join(CONFIG["outdir"], "gan_losses_full.png")
plt.savefig(loss_plot_path)
plt.close()
print("Saved full loss plot to:", loss_plot_path)
# Out:
# Merged with previous history: now 200 epochs total.
# Saved full loss plot to: /projects/standard/fortson/shared/raj00075/outputs_spirals/gan_losses_full.png

# %%
# === Save final generator and discriminator ===
torch.save(gen.state_dict(), os.path.join(CONFIG["gan_ckpt_dir"], "generator_final.pth"))
torch.save(disc.state_dict(), os.path.join(CONFIG["gan_ckpt_dir"], "discriminator_final.pth"))

print("Done training GAN. Checkpoints in:", CONFIG["gan_ckpt_dir"])
# Out:
# Done training GAN. Checkpoints in: /projects/standard/fortson/shared/raj00075/outputs_spirals/gan_checkpoints
